# %%
# importing python libraries NumPy, pandas, Matplotlib and seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# to suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# to read the datafile(in csv format) and import 'DATE' Column into pandas dataframe as Datetime object
ep = pd.read_csv('EnergyProduction.csv',parse_dates = ['DATE'],index_col = 'DATE')

# %%
# to show/print the given dataframe
ep
# Out:
#             EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321
# ...                 ...
# 1989-08-01      75.2704
# 1989-09-01      69.5107
# 1989-10-01      66.0620
# 1989-11-01      69.2555
# 1989-12-01      84.4040
#
# [240 rows x 1 columns]

# %%
# to print the rows from the start and the end
print('Rows from the start\n', ep.head())
print('\n\nRows from the end\n', ep.tail())
# Out:
# Rows from the start
#              EnergyIndex
# DATE
# 1970-01-01      43.0869
# 1970-02-01      42.5577
# 1970-03-01      41.6215
# 1970-04-01      40.1982
# 1970-05-01      39.9321
#
#
# Rows from the end
#              EnergyIndex
# DATE
# 1989-08-01      75.2704
# 1989-09-01      69.5107
# 1989-10-01      66.0620
# 1989-11-01      69.2555
# 1989-12-01      84.4040

# %%
ep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 240 entries, 1970-01-01 to 1989-12-01
# Data columns (total 1 columns):
# EnergyIndex    240 non-null float64
# dtypes: float64(1)
# memory usage: 3.8 KB

# %%
# 
ep.describe()
# Out:
#        EnergyIndex
# count   240.000000
# mean     56.502198
# std       9.043582
# min      39.932100
# 25%      49.799000
# 50%      55.607250
# 75%      62.656200
# max      84.404000

# %%
ep.shape
# Out:
# (240, 1)

# %%
ep.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-02-01', '1970-03-01', '1970-04-01',
#                '1970-05-01', '1970-06-01', '1970-07-01', '1970-08-01',
#                '1970-09-01', '1970-10-01',
#                ...
#                '1989-03-01', '1989-04-01', '1989-05-01', '1989-06-01',
#                '1989-07-01', '1989-08-01', '1989-09-01', '1989-10-01',
#                '1989-11-01', '1989-12-01'],
#               dtype='datetime64[ns]', name='DATE', length=240, freq=None)

# %%
plt.figure(figsize=(15,6))
plt.plot(ep.index, ep['EnergyIndex'])
plt.xlabel('Year'), plt.ylabel('Energy Index'), plt.title('Energy Production')
# Out:
# (Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Energy Index'),
#  Text(0.5, 1.0, 'Energy Production'))

# %%
plt.figure(figsize=(15,6))
plt.scatter(ep.index, ep['EnergyIndex'], color = 'purple')
plt.xlabel('Year'), plt.ylabel('Energy Index'), plt.title('Energy Production')
# Out:
# (Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Energy Index'),
#  Text(0.5, 1.0, 'Energy Production'))

# %%
plt.figure(figsize=(15,6))
plt.bar(ep.index, ep['EnergyIndex'], edgecolor = 'purple')
plt.xlabel('Year'), plt.ylabel('Energy Index'), plt.title('Energy Production')
# Out:
# (Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Energy Index'),
#  Text(0.5, 1.0, 'Energy Production'))

# %%
plt.figure(figsize=(15,6))
sns.set_style('whitegrid')
sns.distplot(ep['EnergyIndex'],bins= 80,hist_kws={'edgecolor':'black'})
plt.title('Energy Index densities'), plt.xlabel('Energy Index'), plt.ylabel('Density')
# Out:
# (Text(0.5, 1.0, 'Energy Index densities'),
#  Text(0.5, 0, 'Energy Index'),
#  Text(0, 0.5, 'Density'))

# %%
#date_series = ep.index
df1 = ep
#df1['DATE'] = date_series
#df1['Year'] = df1['DATE'].dt.year
#df1['Month'] = df1['DATE'].dt.month
df1['Year'] = ep.index.year
df1['Month'] = ep.index.month

# %%
df1
# Out:
#             EnergyIndex  Year  Month
# DATE
# 1970-01-01      43.0869  1970      1
# 1970-02-01      42.5577  1970      2
# 1970-03-01      41.6215  1970      3
# 1970-04-01      40.1982  1970      4
# 1970-05-01      39.9321  1970      5
# ...                 ...   ...    ...
# 1989-08-01      75.2704  1989      8
# 1989-09-01      69.5107  1989      9
# 1989-10-01      66.0620  1989     10
# 1989-11-01      69.2555  1989     11
# 1989-12-01      84.4040  1989     12
#
# [240 rows x 3 columns]

# %%
df1 = ep['EnergyIndex'].resample(rule = 'A').mean()
df1
# Out:
# DATE
# 1970-12-31    41.984625
# 1971-12-31    44.019792
# 1972-12-31    46.784817
# 1973-12-31    49.574850
# 1974-12-31    49.463008
# 1975-12-31    50.520233
# 1976-12-31    52.902583
# 1977-12-31    55.144258
# 1978-12-31    56.530475
# 1979-12-31    57.744783
# 1980-12-31    58.142642
# 1981-12-31    58.948483
# 1982-12-31    56.980392
# 1983-12-31    57.401850
# 1984-12-31    60.807350
# 1985-12-31    62.316367
# 1986-12-31    62.873992
# 1987-12-31    65.911900
# 1988-12-31    69.902892
# 1989-12-31    72.088675
# Freq: A-DEC, Name: EnergyIndex, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.plot(df1.index, df1['EnergyIndex'])
plt.xlabel('Year'), plt.ylabel('Energy Index'), plt.title('Energy Production')
# Out:
# (Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Energy Index'),
#  Text(0.5, 1.0, 'Energy Production'))

# %%
ad = ep.corr()
ad
# Out:
#              EnergyIndex      Year
# EnergyIndex     1.000000  0.842676
# Year            0.842676  1.000000

# %%
df1 = ep
df1['Year'] = ep.index.year
df1['Month'] = ep.index.month
plt.figure(figsize = (15,6))
df1 = df1.pivot('Month','Year','EnergyIndex')
ax = sns.heatmap(df1, cmap = 'YlOrRd')
