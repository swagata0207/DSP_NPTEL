# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Connecting google drive with colab
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_csv('/content/gdrive/My Drive/Datasets/apy.csv')
df
# Out:
#                          State_Name District_Name  ...      Area Production
# 0       Andaman and Nicobar Islands      NICOBARS  ...    1254.0     2000.0
# 1       Andaman and Nicobar Islands      NICOBARS  ...       2.0        1.0
# 2       Andaman and Nicobar Islands      NICOBARS  ...     102.0      321.0
# 3       Andaman and Nicobar Islands      NICOBARS  ...     176.0      641.0
# 4       Andaman and Nicobar Islands      NICOBARS  ...     720.0      165.0
# ...                             ...           ...  ...       ...        ...
# 246086                  West Bengal       PURULIA  ...     306.0      801.0
# 246087                  West Bengal       PURULIA  ...     627.0      463.0
# 246088                  West Bengal       PURULIA  ...     324.0    16250.0
# 246089                  West Bengal       PURULIA  ...  279151.0   597899.0
# 246090                  West Bengal       PURULIA  ...     175.0       88.0
#
# [246091 rows x 7 columns]

# %%
df['Crop'].unique()
# Out:
# array(['Arecanut', 'Other Kharif pulses', 'Rice', 'Banana', 'Cashewnut',
#        'Coconut ', 'Dry ginger', 'Sugarcane', 'Sweet potato', 'Tapioca',
#        'Black pepper', 'Dry chillies', 'other oilseeds', 'Turmeric',
#        'Maize', 'Moong(Green Gram)', 'Urad', 'Arhar/Tur', 'Groundnut',
#        'Sunflower', 'Bajra', 'Castor seed', 'Cotton(lint)', 'Horse-gram',
#        'Jowar', 'Korra', 'Ragi', 'Tobacco', 'Gram', 'Wheat', 'Masoor',
#        'Sesamum', 'Linseed', 'Safflower', 'Onion', 'other misc. pulses',
#        'Samai', 'Small millets', 'Coriander', 'Potato',
#        'Other  Rabi pulses', 'Soyabean', 'Beans & Mutter(Vegetable)',
#        'Bhindi', 'Brinjal', 'Citrus Fruit', 'Cucumber', 'Grapes', 'Mango',
#        'Orange', 'other fibres', 'Other Fresh Fruits', 'Other Vegetables',
#        'Papaya', 'Pome Fruit', 'Tomato', 'Rapeseed &Mustard', 'Mesta',
#        'Cowpea(Lobia)', 'Lemon', 'Pome Granet', 'Sapota', 'Cabbage',
# ...

# %%
df['Season'].unique()
# Out:
# array(['Kharif     ', 'Whole Year ', 'Autumn     ', 'Rabi       ',
#        'Summer     ', 'Winter     '], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246091 entries, 0 to 246090
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   State_Name     246091 non-null  object
#  1   District_Name  246091 non-null  object
#  2   Crop_Year      246091 non-null  int64
#  3   Season         246091 non-null  object
#  4   Crop           246091 non-null  object
#  5   Area           246091 non-null  float64
#  6   Production     242361 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.1+ MB

# %%
df_wb = df[(df['State_Name'] == 'West Bengal') & (df['Crop_Year'] > 2013)]
df_wb
# Out:
#          State_Name       District_Name  ...      Area Production
# 236913  West Bengal  24 PARAGANAS NORTH  ...      54.0      342.0
# 236914  West Bengal  24 PARAGANAS NORTH  ...   15876.0    42913.0
# 236915  West Bengal  24 PARAGANAS NORTH  ...   50694.0   882884.0
# 236916  West Bengal  24 PARAGANAS NORTH  ...     569.0     6202.0
# 236917  West Bengal  24 PARAGANAS NORTH  ...     350.0      403.0
# ...             ...                 ...  ...       ...        ...
# 246086  West Bengal             PURULIA  ...     306.0      801.0
# 246087  West Bengal             PURULIA  ...     627.0      463.0
# 246088  West Bengal             PURULIA  ...     324.0    16250.0
# 246089  West Bengal             PURULIA  ...  279151.0   597899.0
# 246090  West Bengal             PURULIA  ...     175.0       88.0
#
# [503 rows x 7 columns]

# %%
sns.countplot(y='District_Name', data=df_wb)

# %%
df_wb_sp1 = df_wb[(df_wb['Crop'] == 'Rice') & (df_wb['Season'] == 'Summer     ')]
df_wb_sp1
# Out:
#          State_Name       District_Name  Crop_Year  ...  Crop      Area  Production
# 236934  West Bengal  24 PARAGANAS NORTH       2014  ...  Rice   70898.0    239229.0
# 237365  West Bengal  24 PARAGANAS SOUTH       2014  ...  Rice   63392.0    211431.0
# 237990  West Bengal             BANKURA       2014  ...  Rice   40185.0    120678.0
# 238594  West Bengal           BARDHAMAN       2014  ...  Rice  150267.0    490532.0
# 239162  West Bengal             BIRBHUM       2014  ...  Rice   66581.0    225789.0
# 239733  West Bengal          COOCHBEHAR       2014  ...  Rice   56294.0    197210.0
# 240307  West Bengal          DARJEELING       2014  ...  Rice    1516.0      3437.0
# 240707  West Bengal    DINAJPUR DAKSHIN       2014  ...  Rice   16722.0     56152.0
# 241301  West Bengal      DINAJPUR UTTAR       2014  ...  Rice   37599.0    131609.0
# 241727  West Bengal             HOOGHLY       2014  ...  Rice   79654.0    261105.0
# ...

# %%
df_wb_sp1['Production per unit area'] = (df_wb_sp1['Production'])/(df_wb_sp1['Area'])
df_wb_sp1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          State_Name       District_Name  ...  Production Production per unit area
# 236934  West Bengal  24 PARAGANAS NORTH  ...    239229.0                 3.374270
# 237365  West Bengal  24 PARAGANAS SOUTH  ...    211431.0                 3.335295
# 237990  West Bengal             BANKURA  ...    120678.0                 3.003061
# 238594  West Bengal           BARDHAMAN  ...    490532.0                 3.264403
# 239162  West Bengal             BIRBHUM  ...    225789.0                 3.391193
# 239733  West Bengal          COOCHBEHAR  ...    197210.0                 3.503215
# ...

# %%
df_wb_sp2 = df_wb[(df_wb['Crop'] == 'Rice') & (df_wb['Season'] == 'Winter     ')]
df_wb_sp2
# Out:
#          State_Name       District_Name  Crop_Year  ...  Crop      Area  Production
# 236937  West Bengal  24 PARAGANAS NORTH       2014  ...  Rice  139767.0    401623.0
# 237368  West Bengal  24 PARAGANAS SOUTH       2014  ...  Rice  325501.0    794541.0
# 237993  West Bengal             BANKURA       2014  ...  Rice  294204.0    794716.0
# 238597  West Bengal           BARDHAMAN       2014  ...  Rice  419814.0   1361138.0
# 239165  West Bengal             BIRBHUM       2014  ...  Rice  315561.0   1029374.0
# 239737  West Bengal          COOCHBEHAR       2014  ...  Rice  217046.0    515777.0
# 240310  West Bengal          DARJEELING       2014  ...  Rice   27135.0     56945.0
# 240708  West Bengal    DINAJPUR DAKSHIN       2014  ...  Rice  163582.0    462884.0
# 241304  West Bengal      DINAJPUR UTTAR       2014  ...  Rice  179862.0    466273.0
# 241730  West Bengal             HOOGHLY       2014  ...  Rice  190221.0    580845.0
# ...

# %%
df_wb_sp3 = df_wb[(df_wb['Season'] == 'Whole Year ')]
df_wb_sp3
# Out:
#          State_Name       District_Name  ...     Area Production
# 236936  West Bengal  24 PARAGANAS NORTH  ...    885.0    82334.0
# 237367  West Bengal  24 PARAGANAS SOUTH  ...     26.0     2419.0
# 237992  West Bengal             BANKURA  ...      5.0      393.0
# 238596  West Bengal           BARDHAMAN  ...   1440.0   113754.0
# 239164  West Bengal             BIRBHUM  ...    717.0    60810.0
# 239735  West Bengal          COOCHBEHAR  ...    455.0    48692.0
# 239736  West Bengal          COOCHBEHAR  ...  13437.0    22780.0
# 240309  West Bengal          DARJEELING  ...      2.0      214.0
# 241303  West Bengal      DINAJPUR UTTAR  ...    425.0    45481.0
# 241729  West Bengal             HOOGHLY  ...    830.0   149289.0
# 242100  West Bengal              HOWRAH  ...      2.0      186.0
# 242731  West Bengal          JALPAIGURI  ...    250.0    26754.0
# 242732  West Bengal          JALPAIGURI  ...    627.0      931.0
# ...
